# %%
from splinter import Browser
from bs4 import BeautifulSoup
from random import randint
import datetime
import os
import json
import time
import re

# Sets the root url
root_url = 'https://www.glassdoor.com'

# Sets the search parameters
time_period = "Last Day"
keyword = 'Data Scientist'
location = 'United States'
# Set path variables

corpus_path = '/Users/grothjd/DS_bootcamp/jobsearch_dashboard/corpus5/'



# Sets the path to the chrome driver
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# directs the browser to visit the root site and sleeps for 2 seconds
browser.visit(root_url)
time.sleep(2)

# Fills out the form for job title and location and sleeps for 2 seconds
browser.find_by_xpath("//input[@id='KeywordSearch']").fill(keyword)
browser.find_by_xpath("//input[@id='LocationSearch']").fill(location)
browser.find_by_id('HeroSearchButton').click()
time.sleep(2)

# Select date posted drop down and Set date range to search
browser.find_by_text("Date Posted").click()
time.sleep(1)
browser.find_by_text(time_period).click()
time.sleep(randint(1,3))

# %%
# initialize page count
n = 1

# run while there is still a next button
while True:
    try:
        x_button = browser.find_by_css('div.xBtn')
        if x_button:
            x_button.click()
    except Exception as e:
        print(e)
    test_url = browser.url
    
    
    #creates directory to save all files
    date = datetime.datetime.strftime(datetime.datetime.now(), '%d-%m-%Y')
    path = corpus_path + date + '/Page_' + str(n) + '/'
    if not os.path.exists(path):
        os.makedirs(path) 

    
    
    elements = browser.find_by_xpath("//li[@class='jl']")
    
    for element in elements:
        try:
            x_button = browser.find_by_css('div.xBtn')
            if x_button:
                x_button.click()
        except Exception as e:
            print(e)
        try:
            element.click()
            time.sleep(2)
            job_title = browser.find_by_xpath("//h1[@class='jobTitle h2 strong']")

            #print(job_title.html)


            job_title = job_title.html

            job_title = str(job_title)

            company = str(browser.find_by_xpath("//a[@class='plain strong empDetailsLink']").html)
            print(company)

            company_info = browser.find_by_xpath("//div[@class='compInfo']")

            if len(company_info.find_by_tag('span')) == 2:
                city_state = str(company_info.find_by_tag('span')[1].html)
                rating = str(company_info.find_by_tag('span')[0].html)
                rating = rating[0:3]
                print(city_state)

                print(rating)
            elif len(company_info.find_by_tag('span')) == 1:
                city_state = company_info.find_by_tag('span').html
                rating = 'NA'
                print(city_state)
                print(rating)

            job_description = str(browser.find_by_xpath("//div[@class='jobDescriptionContent desc']").html)

            date = datetime.datetime.strftime(datetime.datetime.now(), '%d-%m-%Y')

            job = {'job title': job_title, 'company': company, 'city state': city_state, 'rating': rating, 'job description': job_description}

            try:
                filename = company.replace(" ", "") + '-' + job_title.replace(" ", "").replace("/", "-") + '.json'
                with open(path + filename, 'w') as f:
                    f.write(json.dumps(job))
                    print('Saved to file : ' + filename)
            except Exception as e:
                print(e)
            time.sleep(2)
        except Exception as e:
            print(e)
    
    next_button = browser.find_by_css('li.next')
    if next_button:
        next_button.click()
        time.sleep(randint(1,10))
    else:
        break
    n += 1
# Out:
# Quora, Inc.
# – Mountain View, CA
# 4.6
# Saved to file : Quora,Inc.-DataScientist.json
# Mission Bell Manufacturing
# – Morgan Hill, CA
# 3.9
# Saved to file : MissionBellManufacturing-DataScientist.json
# Proofpoint
# – Draper, UT
# 3.2
# Saved to file : Proofpoint-DataScientist.json
# Plymouth Rock Assurance
# –
# 4.0
# Saved to file : PlymouthRockAssurance-DataScientist.json
# Tailored Management
# – Jacksonville, FL
# 4.1
# Saved to file : TailoredManagement-DataScientist.json
# Audley Travel
# – Boston, Massachusetts
# 4.4
# Saved to file : AudleyTravel-DataEngineer.json
# Rainforest Alliance
# – Remote
# 3.1
# Saved to file : RainforestAlliance-DataScientist.json
# Novetta
# – Herndon, VA
# 3.6
# Saved to file : Novetta-DataScientist.json
# Hilton Software
# – Coral Springs, FL
# NA
# Saved to file : HiltonSoftware-PythonDeveloperDataEngineer.json
# Bioclinica
# – Durham, NC
# 2.7
# Saved to file : Bioclinica-DataScientist.json
# Apple
# – Austin, Texas
# 4.0
# Saved to file : Apple-DataScientist.json
# L.L. Bean
# – US-ME-Freeport
# 3.5
# Saved to file : L.L.Bean-DataScientist.json
# ZestFinance
# – Pittsburgh, PA, United States
# 3.8
# Saved to file : ZestFinance-DataScientist,MachineLearning.json
# Banner Health
# – US-AZ-Phoenix
# 3.4
# Saved to file : BannerHealth-DataScientist.json
# Cerner
# – United States Kansas City, Missouri
# 3.5
# Saved to file : Cerner-DataScientist.json
# Boxy Charm
# – Pembroke Pines, FL
# 3.2
# Saved to file : BoxyCharm-DataScientist,Algorithms&amp;DataSystems.json
# West Pharmaceutical Services
# – Exton, Pennsylvania
# 3.0
# Saved to file : WestPharmaceuticalServices-Scientist,Lab.json
# Hired
# – MILL CREEK, WA
# 4.0
# Saved to file : Hired-DataScientist.json
# Beeswax
# – New York, NY
# 4.9
# Saved to file : Beeswax-DataScientist.json
# BARK
# – New York, NY
# 3.5
# Saved to file : BARK-DataScientist.json
# Zynga
# – San Francisco, CA, United States
# 3.8
# Saved to file : Zynga-DataScientist4,WordswithFriends.json
# Amazon
# – Broomfield, CO
# 3.8
# Saved to file : Amazon-DataScientistII.json
# Loma Linda University Medical Center
# – Loma Linda, CA
# 3.9
# Saved to file : LomaLindaUniversityMedicalCenter-ClinicalLabScientist.json
# NEXTGEN GLOBAL RESOURCES
# – Walnut Creek, California
# 4.6
# Saved to file : NEXTGENGLOBALRESOURCES-DataScientistIV.json
# NetApp
# – Waltham, MA
# 3.6
# Saved to file : NetApp-DataScientist.json
# newcareers
# – Cherry Hill, NJ
# 5.0
# Saved to file : newcareers-DataScientist.json
# Presbyterian Healthcare Services
# – Albuquerque, NM
# 3.5
# Saved to file : PresbyterianHealthcareServices-LEADSCIENTIST-PHPINFORMATICS-Relocateto.json
# Presbyterian Healthcare Services
# – New Orleans, LA
# 3.5
# Saved to file : PresbyterianHealthcareServices-LEADSCIENTIST-PHPINFORMATICS-RelocatetoAlbuquerque,NM.json
# Momentive Performance Materials
# – US NY Tarrytown
# 3.8
# Saved to file : MomentivePerformanceMaterials-SrProductDevScientist-CoatingAdditives.json
# Message: element not visible
#   (Session info: chrome=70.0.3538.102)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.14.1 x86_64)
#
# Quora, Inc.
# – Mountain View, CA
# 4.6
# Saved to file : Quora,Inc.-DataScientist.json
# Message: element not visible
#   (Session info: chrome=70.0.3538.102)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.14.1 x86_64)
#
# Postmates Inc.
# – Bellevue, WA
# 3.3
# Saved to file : PostmatesInc.-DataScientist-Risk.json
# Message: element not visible
#   (Session info: chrome=70.0.3538.102)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.14.1 x86_64)
#
# Fama (CA)
# – Playa Vista, California
# 5.0
# Saved to file : Fama(CA)-JuniorDataScientist.json
# Message: element not visible
#   (Session info: chrome=70.0.3538.102)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.14.1 x86_64)
#
# ICF
# – Olympia, WA
# 3.6
# Saved to file : ICF-DataScientist.json
# Message: element not visible
#   (Session info: chrome=70.0.3538.102)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.14.1 x86_64)
#
# Corning
# – Corning, NY, US, 14830
# 3.7
# Saved to file : Corning-DataScientist.json
# Message: element not visible
#   (Session info: chrome=70.0.3538.102)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.14.1 x86_64)
#
# Yale University
# – New Haven, CT
# 4.3
# Saved to file : YaleUniversity-DataScientist.json
# Message: element not visible
#   (Session info: chrome=70.0.3538.102)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.14.1 x86_64)
#
# DuPont
# – United States-Delaware-Wilmington
# 3.6
# Saved to file : DuPont-DigitalAnalyst-DataScientists.json
# Message: element not visible
#   (Session info: chrome=70.0.3538.102)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.14.1 x86_64)
#
# XPO Logistics
# – High Point, NC
# 3.7
# Saved to file : XPOLogistics-DataScientist.json
# Message: element not visible
#   (Session info: chrome=70.0.3538.102)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.14.1 x86_64)
#
# Wegmans Food Markets
# – Rochester
# 4.0
# Saved to file : WegmansFoodMarkets-DataScientist.json
# Message: element not visible
#   (Session info: chrome=70.0.3538.102)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.14.1 x86_64)
#
# Eliassen
# – Boston, MA
# 4.4
# Saved to file : Eliassen-DataAnalyst.json
# Message: element not visible
#   (Session info: chrome=70.0.3538.102)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.14.1 x86_64)
#
# VoiceGlance
# – Albany, New York
# 4.5
# Saved to file : VoiceGlance-DataScientist.json
# Message: element not visible
#   (Session info: chrome=70.0.3538.102)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.14.1 x86_64)
#
# Red Lambda
# – Longwood, FL
# 3.2
# Saved to file : RedLambda-DataScientist.json
# Message: element not visible
#   (Session info: chrome=70.0.3538.102)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.14.1 x86_64)
#
# Kensho Technologies
# – Massachusetts, Massachusetts
# 5.0
# Saved to file : KenshoTechnologies-DataScientist.json
# Message: element not visible
#   (Session info: chrome=70.0.3538.102)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.14.1 x86_64)
#
# Baidu USA
# – Sunnyvale, CA
# 4.2
# Saved to file : BaiduUSA-ComputerVisionScientist-Engineer.json
# Message: element not visible
#   (Session info: chrome=70.0.3538.102)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.14.1 x86_64)
#
# Niantic
# – San Francisco, CA
# 4.7
# Saved to file : Niantic-DataScientist.json
# Message: element not visible
#   (Session info: chrome=70.0.3538.102)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.14.1 x86_64)
#
# Diverse Lynx
# – Bentonville, Arkansas
# 3.9
# Saved to file : DiverseLynx-DataScientist.json
# Message: element not visible
#   (Session info: chrome=70.0.3538.102)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.14.1 x86_64)
#
# Acuity INC
# – US-VA-Reston
# 3.8
# Saved to file : AcuityINC-DataScientist.json
# Message: element not visible
#   (Session info: chrome=70.0.3538.102)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.14.1 x86_64)
#
# Jacobs
# – Washington, DC
# 3.4
# Saved to file : Jacobs-DataScientist.json
# Message: element not visible
#   (Session info: chrome=70.0.3538.102)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.14.1 x86_64)
#
# System Soft Technologies
# – Jacksonville, Florida
# 3.7
# Saved to file : SystemSoftTechnologies-DataScientist.json
# Message: element not visible
#   (Session info: chrome=70.0.3538.102)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.14.1 x86_64)
#
# MacB
# – Linthicum Heights, Maryland
# 3.5
# Saved to file : MacB-DataScientist.json
# Message: element not visible
#   (Session info: chrome=70.0.3538.102)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.14.1 x86_64)
# Ascena Retail Group
# – Ascena Corp ETNA-ascena-Pataskala, OH 43062
# 3.2
# Saved to file : AscenaRetailGroup-DataScientist.json
# Message: element not visible
#   (Session info: chrome=70.0.3538.102)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.14.1 x86_64)
#
# SoftPath Technologies
# – Sunnyvale, CA
# 3.1
# Saved to file : SoftPathTechnologies-DataScientist.json
# Message: element not visible
#   (Session info: chrome=70.0.3538.102)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.14.1 x86_64)
#
# SAP
# – Palo Alto, CA
# 4.5
# Saved to file : SAP-DataScientist.json
# Message: element not visible
#   (Session info: chrome=70.0.3538.102)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.14.1 x86_64)
#
# S&amp;P Global
# – New York, NY US
# 3.5
# Saved to file : S&amp;PGlobal-DataScientist.json
# Message: element not visible
#   (Session info: chrome=70.0.3538.102)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.14.1 x86_64)
#
# Hunter Technical Resources
# – Alpharetta, GA
# 4.8
# Saved to file : HunterTechnicalResources-DataScientist.json
# Message: element not visible
#   (Session info: chrome=70.0.3538.102)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.14.1 x86_64)
#
# Robert Half
# – San Mateo, CA
# 3.3
# Saved to file : RobertHalf-DataScientist.json
# Message: element not visible
#   (Session info: chrome=70.0.3538.102)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.14.1 x86_64)
#
# Kani Solutions
# – Chicago, Illinois
# 4.8
# Saved to file : KaniSolutions-DataScientist.json
# Message: element not visible
#   (Session info: chrome=70.0.3538.102)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.14.1 x86_64)
#
# CyberCoders
# – La Grange, KY
# 4.0
# Saved to file : CyberCoders-DataScientist.json
# Message: element not visible
#   (Session info: chrome=70.0.3538.102)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.14.1 x86_64)
#
# Novetta
# – Herndon, VA
# 3.6
# Saved to file : Novetta-SeniorDataScientist.json
# Message: element not visible
#   (Session info: chrome=70.0.3538.102)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.14.1 x86_64)
#
# Lightspeed Systems
# – Austin, TX
# 4.2
# Saved to file : LightspeedSystems-DataAnalyticsDeveloper-DataScientist.json
# Message: element not visible
#   (Session info: chrome=70.0.3538.102)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.14.1 x86_64)
#
# Agios Pharmaceuticals
# – Cambridge, MA
# 3.9
# Saved to file : AgiosPharmaceuticals-SeniorScientist,ProcessChemistry.json
# Banner Health
# – US-AZ-Phoenix
# 3.4
# Saved to file : BannerHealth-DataScientist.json
# Blackbaud
# – Charleston (Customer Operations Center) - South Carolina -
# 3.1
# Saved to file : Blackbaud-DataAnalyst.json
# Campbell Soup Company
# – USA - NJ - Camden
# 3.2
# Saved to file : CampbellSoupCompany-DataScientist.json
# Amazon
# – Sunnyvale, CA
# 3.8
# Saved to file : Amazon-MachineLearningScientist.json
# Groupon
# – Chicago, United States
# 3.6
# Saved to file : Groupon-DataScientist.json
# Bloomberg
# – New York City, New York
# 3.7
# Saved to file : Bloomberg-PythonDataScientist.json
# Amazon
# – Seattle, WA
# 3.8
# Saved to file : Amazon-DataEngineer.json
# Globant
# – Stamford, CT
# 3.7
# Saved to file : Globant-DataScientist.json
# ExtraHop Networks, Inc.
# – Seattle, WA, United States
# 4.1
# Saved to file : ExtraHopNetworks,Inc.-AssociateDataScientist.json
# Fresenius Kabi USA
# – Melrose Park
# 2.4
# Saved to file : FreseniusKabiUSA-ASSOCIATESCIENTIST.json
# CNH Industrial
# – Burr Ridge, Illinois
# 3.1
# Saved to file : CNHIndustrial-DataScientist.json
# Philips
# – Pleasanton
# 3.4
# Saved to file : Philips-DataScientist.json
# ON Semiconductor
# – Phoenix, AZ
# 3.6
# Saved to file : ONSemiconductor-DataScientist.json
# Kelly Mitchell Group
# – Irving, TX
# 3.5
# Saved to file : KellyMitchellGroup-DataScientist.json
# Code Pilot
# – Austin, TX
# NA
# Saved to file : CodePilot-DataScientist.json
# First Soft Solutions [ Direct]
# – Sunnyvale, California
# NA
# Saved to file : FirstSoftSolutions[Direct]-DataScientist.json
# Merck
# – Kenilworth, NJ, US
# 3.7
# Saved to file : Merck-DataScientist.json
# Berico Technologies
# – Springfield, VA
# 3.5
# Saved to file : BericoTechnologies-DataScientist.json
# Homes.com
# – Beverly
# 4.2
# Saved to file : Homes.com-AutomotiveDataAnalyst.json
# The Aerospace Corporation
# – El Segundo, CA
# 3.7
# Saved to file : TheAerospaceCorporation-DataScientist.json
# Spectraforce Technologies Inc
# – Basking Ridge, New Jersey
# 3.6
# Saved to file : SpectraforceTechnologiesInc-DataScientist.json
# MedStar Health
# – Washington, DC
# 3.5
# Saved to file : MedStarHealth-DataScientist.json
# First Soft Solutions LLC
# – Mountain View, California
# 1.4
# Saved to file : FirstSoftSolutionsLLC-DataScientist.json
# Message: unknown error: Element <li class="jl" data-id="2948038052" data-emp-id="558420" data-is-organic-job="false" data-ad-order-id="413755" data-sgoc-id="1019" data-purchase-ad-order-id="0" data-is-easy-apply="false" data-normalize-job-title="data scientist intern" data-job-loc="Seattle, WA" data-job-loc-id="1150505" data-job-loc-type="C" data-njslv="false">...</li> is not clickable at point (331, 247). Other element would receive the click: <iframe frameborder="0" marginwidth="0" marginheight="0" allowtransparency="true" scrolling="no" width="100%" name="{&quot;name&quot;:&quot;master-1&quot;,&quot;slave-1-1&quot;:{&quot;container&quot;:&quot;adcontainer2&quot;,&quot;linkTarget&quot;:&quot;_blank&quot;,&quot;lines&quot;:2,&quot;colorText&quot;:&quot;#333333&quot;,&quot;colorTitleLink&quot;:&quot;#0066cc&quot;,&quot;colorDomainLink&quot;:&quot;#007600&quot;,&quot;fontSizeTitle&quot;:&quot;13px&quot;,&quot;fontSizeDescription&quot;:&quot;13px&quot;,&quot;fontSizeAttribution&quot;:&quot;13px&quot;,&quot;rolloverAdBackgroundColor&quot;:&quot;#F1F1F1&quot;,&quot;type&quot;:&quot;ads&quot;,&quot;columns&quot;:1,&quot;horizontalAlignment&quot;:&quot;left&quot;,&quot;resultsPageQueryParam&quot;:&quot;query&quot;},&quot;master-1&quot;:{&quot;container&quot;:&quot;adcontainer1&quot;,&quot;linkTarget&quot;:&quot;_blank&quot;,&quot;lines&quot;:2,&quot;colorText&quot;:&quot;#333333&quot;,&quot;colorTitleLink&quot;:&quot;#0066cc&quot;,&quot;colorDomainLink&quot;:&quot;#007600&quot;,&quot;fontSizeTitle&quot;:&quot;13px&quot;,&quot;fontSizeDescription&quot;:&quot;13px&quot;,&quot;fontSizeAttribution&quot;:&quot;13px&quot;,&quot;rolloverAdBackgroundColor&quot;:&quot;#F1F1F1&quot;,&quot;type&quot;:&quot;ads&quot;,&quot;columns&quot;:1,&quot;horizontalAlignment&quot;:&quot;left&quot;,&quot;resultsPageQueryParam&quot;:&quot;query&quot;}}" id="master-1" src="https://www.google.com/afs/ads?q=Data%20Scientist%20career&amp;r=m&amp;client=pub-4602098854390349&amp;channel=0641790025%2B8721303385&amp;type=0&amp;oe=UTF-8&amp;ie=UTF-8&amp;fexp=21404%2C17300003&amp;format=n2%7Cn2&amp;ad=n4&amp;nocache=1901542116822197&amp;num=0&amp;output=uds_ads_only&amp;v=3&amp;adext=as1%2Csr1&amp;bsl=10&amp;u_his=6&amp;u_tz=-300&amp;dt=1542116822197&amp;u_w=1440&amp;u_h=900&amp;biw=1200&amp;bih=655&amp;psw=1200&amp;psh=655&amp;frm=0&amp;uio=sl1sr1-af2st13sd13sa13-af2st13sd13sa13&amp;jsv=10488&amp;rurl=https%3A%2F%2Fwww.glassdoor.com%2FJob%2Fus-data-scientist-jobs-SRCH_IL.0%2C2_IN1_KO3%2C17_IP3.htm%3FfromAge%3D1&amp;referer=https%3A%2F%2Fwww.glassdoor.com%2F#master-1" style="visibility: visible; height: 277px;" title="Ads by Google"></iframe>
#   (Session info: chrome=70.0.3538.102)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.14.1 x86_64)
#
# DISH Network
# – Englewood, CO
# 2.8
# Saved to file : DISHNetwork-DataScientist.json
# Horizontal Integration
# – Downtown, FL, United States
# 4.0
# Saved to file : HorizontalIntegration-DataScientist.json
# Donnelley Financial Solutions
# – Chicago, IL
# 2.7
# Saved to file : DonnelleyFinancialSolutions-DataScientist.json
# Marvell Technology
# – United States, California, San Jose
# 3.7
# Saved to file : MarvellTechnology-CloudStorage&amp;BigDataPerformanceArchitect.json
# DataRobot
# – San Francisco, CA
# 4.3
# Saved to file : DataRobot-CustomerFacingDataScientist.json
# Grant Thornton
# – New York - Manhattan(641) (641) 757 3rd Avenue #9 New York, 10017 Charlotte(131) (131) 201 South College Street Sui
# 3.7
# Saved to file : GrantThornton-FinTechSeniorAssociate-DataScientist.json
# AmerisourceBergen
# – United States
# 3.0
# Saved to file : AmerisourceBergen-LeadDataEngineer.json
# Hired
# – MILL CREEK, WA
# 4.0
# Saved to file : Hired-DataScientist.json
# Business Technology Group
# – Jacksonville, Florida
# 5.0
# Saved to file : BusinessTechnologyGroup-DataScientistI.json
# Gilead Sciences
# – Foster City, CA (US)
# 3.2
# Saved to file : GileadSciences-ResearchScientistI,StructuralChemistry.json
# The Broad Institute
# – Cambridge, MA
# 4.3
# Saved to file : TheBroadInstitute-ComputationalScientistI.json
# RBC
# – Jersey City, New Jersey
# 3.7
# Saved to file : RBC-DataScientist,RBCAmplify.json
# Niantic
# – Sunnyvale, CA
# 4.7
# Saved to file : Niantic-DataScientist,MachineLearning.json
# Riverside Technology, inc.
# – College Park, MD
# 4.0
# Saved to file : RiversideTechnology,inc.-DataScientist-SoftwareProgrammer(NOAA-STAR).json
# ICF
# – Bethesda, MD
# 3.6
# Saved to file : ICF-SeniorHealthDataAnalyst-Scientist.json
# Citibank
# – New York
# 3.4
# Saved to file : Citibank-DataScientist-InnovationLab.json
# Visa Inc.
# – Washington, DC
# 3.4
# Saved to file : VisaInc.-DataScientist-Sr.DataScientist.json
# CitiGroup
# – NAM-USA-NY-New York
# 3.5
# Saved to file : CitiGroup-DataScientist-InnovationLab.json
# Adobe
# – San Jose
# 4.1
# Saved to file : Adobe-ComputerScientist,DataScienceWorkspace.json
# VanderHouwen
# – Redwood City, California
# 4.5
# Saved to file : VanderHouwen-DataAnalyst.json
# Montefiore Medical Center
# – YONKERS, NY
# 3.5
# Saved to file : MontefioreMedicalCenter-DATASCIENTIST.json
# Taboola
# – New York, NY
# 3.9
# Saved to file : Taboola-DataEngineer,PeopleAnalytics.json
# Electric Power Research Institute, Inc.
# – Knoxville, TN
# 3.7
# Saved to file : ElectricPowerResearchInstitute,Inc.-Engineer-ScientistII-DataAnalytics.json
# Amazon
# – Seattle, WA
# 3.8
# Saved to file : Amazon-AppliedScientist.json
# Technology Partners
# – Saint Louis, MO
# 4.5
# Saved to file : TechnologyPartners-DataScientist-Intermediate.json
# APEX Systems
# – Broomfield, Colorado
# 3.2
# Saved to file : APEXSystems-DataScientistII.json
# Satsyil Corporation
# – Alexandria, Virginia
# 4.4
# Saved to file : SatsyilCorporation-SeniorDataScientist.json
# Light
# – Palo Alto
# 4.9
# Saved to file : Light-computationalimagingresearchscientist.json
# NVIDIA
# – Redmond, WA
# 4.5
# Saved to file : NVIDIA-ComputerVisionScientist.json
# Citadel Securities
# – New York
# 4.9
# Saved to file : CitadelSecurities-QuantitativeResearcher–Intern(US).json
# Fuel Talent
# – Seattle, WA
# 5.0
# Saved to file : FuelTalent-SeniorDataScientist.json
# Endurance International Group
# – Burlington, MA
# 3.1
# Saved to file : EnduranceInternationalGroup-SeniorDataScientist.json
# FabFitFun
# – Los Angeles, CA
# 4.0
# Saved to file : FabFitFun-SeniorDataScientist.json
# Pharmacyclics
# – Sunnyvale, CA
# 2.4
# Saved to file : Pharmacyclics-SeniorScientistI,DMPK.json
# CarGurus
# – Cambridge, MA
# 4.6
# Saved to file : CarGurus-SeniorDataScienceEngineer-Algorithmic.json
# Demandbase
# – San Francisco, CA
# 4.5
# Saved to file : Demandbase-PrincipalDataEngineer.json
# Alexion Pharmaceuticals
# – Boston, MA
# 2.5
# Saved to file : AlexionPharmaceuticals-SrManager,SafetyScientist.json
# Baidu USA
# – Sunnyvale, CA
# 4.2
# Saved to file : BaiduUSA-SeniorResearchScientist(VideoAnalysis-ComputerVision-NetworkArchitecturalSearch).json
# Cerner
# – Malvern, PA
# 3.5
# Saved to file : Cerner-DataScientist.json
# 84.51°
# – Chicago
# 4.2
# Saved to file : 84.51°-LeadDataScientist,Insights.json
# PayPal
# – San Jose
# 3.7
# Saved to file : PayPal-BigDataEngineer.json
# Accent Technologies, Inc.
# – Melbourne, FL
# 4.0
# Saved to file : AccentTechnologies,Inc.-AdvancedDataScientistConsultant.json
# Kensho Technologies
# – Los Angeles, California
# 5.0
# Saved to file : KenshoTechnologies-MachineLearningEngineer-DataScientist.json
# Doximity
# – San Francisco, CA
# 4.2
# Saved to file : Doximity-DataManager.json
# McKinsey &amp; Company
# – New York, New York
# 4.3
# Saved to file : McKinsey&amp;Company-DataScientist-JourneyAnalytics.json
# Service Titan
# – Glendale
# 4.0
# Saved to file : ServiceTitan-DataScientist,Strategy.json
# Infosys
# – New York, NY
# 3.3
# Saved to file : Infosys-AssociateDataScientist.json
# Microsoft Corporation
# – Redmond, WA
# 4.1
# Saved to file : MicrosoftCorporation-Data&amp;AppliedScientist.json
# Profiles
# – Fairfax, VA
# 4.2
# Saved to file : Profiles-MarketingDataScientist.json
# J.P. Morgan
# – Tampa
# 3.8
# Saved to file : J.P.Morgan-CapacityPlanningDataScientist.json
# Amplify Professional Services
# – Irvine, CA
# NA
# Saved to file : AmplifyProfessionalServices-DataScientist-Marketing.json
# Etsy
# – New York, NY
# 3.8
# Saved to file : Etsy-DataScientist-AI-ML.json
# Bread
# – New York City, NY, US
# 5.0
# Saved to file : Bread-DataScienceLead.json
# Microsoft Corporation
# – Bellevue, WA
# 4.1
# Saved to file : MicrosoftCorporation-SeniorData&amp;AppliedScientist.json
# Johns Hopkins University Applied Physics Laboratory
# – Laurel, Maryland
# 4.6
# Saved to file : JohnsHopkinsUniversityAppliedPhysicsLaboratory-SystemsAnalyst-DataScientist.json
# Citadel Federal Credit Union
# – Exton,PA
# 3.8
# Saved to file : CitadelFederalCreditUnion-DigitalAnalyticsManager.json
# Citibank
# – Irving, Texas
# 3.4
# Saved to file : Citibank-DataScientist-Sr.ProgrammerAnalyst.json
# Experian Ltd
# – Costa Mesa, California
# 3.6
# Saved to file : ExperianLtd-SeniorDataScientist.json
# Lacework
# – Mountain View, California
# 4.8
# Saved to file : Lacework-Business-DataAnalyst-WinterIntern(January-April).json
# Moat
# – New York, NY
# 3.1
# Saved to file : Moat-SeniorDataScientist.json
# Primer AI
# – San Francisco, CA
# 4.3
# Saved to file : PrimerAI-SeniorDataScientist.json
# WeWork
# – Boston, MA
# 3.3
# Saved to file : WeWork-PrincipalScientist,AppliedScience.json
# AMRI
# – US-NY-Albany
# 2.8
# Saved to file : AMRI-SeniorResearchScientist-Extractable,Leachable&amp;ImpuritiesDepartment.json
# Advanced Systems Engineering Corporation
# – US-VA-Mclean
# 5.0
# Saved to file : AdvancedSystemsEngineeringCorporation-SeniorDataScientist.json
# CyberCoders
# – Palo Alto, CA
# 4.0
# Saved to file : CyberCoders-ChiefDataScientist.json
# ASICS Digital
# – Greater Boston Area
# 4.6
# Saved to file : ASICSDigital-LeadDataEngineer.json
# CyberCoders
# – Boston, MA
# 4.0
# Saved to file : CyberCoders-PrincipalDataScientist.json
# CyberCoders
# – Culver City, CA
# 4.0
# Saved to file : CyberCoders-LeadDataScientist.json
# CyberCoders
# – New York City, NY
# 4.0
# Saved to file : CyberCoders-SeniorDataScientist.json
# Novetta
# – Herndon, VA
# 3.6
# Saved to file : Novetta-DataScientist.json
# IBM (United Kingdom) Ltd
# – Cairo, Alabama
# NA
# Saved to file : IBM(UnitedKingdom)Ltd-SeniorDataScientist.json
# Spirent Communications
# – Holmdel, NJ
# 3.6
# Saved to file : SpirentCommunications-AssociateDataScientist.json
# AmerisourceBergen
# – Cleveland, MS
# 3.0
# Saved to file : AmerisourceBergen-Scientist.json
# AmerisourceBergen
# – Cleveland, MS
# 3.0
# Saved to file : AmerisourceBergen-Scientist.json
# Schneider
# – USA-WISCONSIN-Green Bay
# 3.3
# Saved to file : Schneider-DataScientistI.json
# Phillips 66
# – Houston, TX
# 3.5
# Saved to file : Phillips66-2019UniversityIntern-DataScientist-Engineer.json
# Integrated Resources, Inc.
# – San Diego, California
# 3.8
# Saved to file : IntegratedResources,Inc.-Scientist.json
# Synectics Inc.
# – Pearl River, NY
# 3.4
# Saved to file : SynecticsInc.-Scientist.json
# Aetna Inc.
# – Hartford, Connecticut
# 3.4
# Saved to file : AetnaInc.-PrincipalDataScientist-DataHub.json
# Uber
# – San Francisco, California
# 4.2
# Saved to file : Uber-DataAnalystI,SafetyandInsurance.json
# ICF
# – Golden, CO
# 3.6
# Saved to file : ICF-Statistician-DataScientist.json
# comScore
# – US-VA-Reston
# 3.0
# Saved to file : comScore-CustomDataAnalyst.json
# Chase
# – Tampa
# 3.6
# Saved to file : Chase-CapacityPlanningDataScientist.json
# Eliassen Group
# – Hopkinton, MA
# 4.4
# Saved to file : EliassenGroup-BusinessOperationsDataAnalyst.json
# Amazon
# – Seattle, WA
# 3.8
# Saved to file : Amazon-PrincipalResearchScientist.json
# KAYAK
# – Cambridge, MA, United States
# 4.1
# Saved to file : KAYAK-SeniorDataScientist(Marketing).json
# Stitch Fix
# – San Francisco, CA
# 3.3
# Saved to file : StitchFix-DataScientist-MerchScenarios.json
# Lexmark International
# – Lexington, KY
# 3.3
# Saved to file : LexmarkInternational-SeniorDataScientist.json
# CGI Group, Inc.
# – Bloomfield, CT
# 3.4
# Saved to file : CGIGroup,Inc.-DataScientist-Engineer.json
# MasterCard
# – San Francisco, California
# 4.0
# Saved to file : MasterCard-Manager,DataScientist-Brighterion.json
# 84.51°
# – Chicago
# 4.2
# Saved to file : 84.51°-LeadDataScientist,MachineLearning.json
# Freddie Mac
# – Mc Lean, VA
# 3.8
# Saved to file : FreddieMac-SeniorDataScientist.json
# Amazon
# – Seattle, WA
# 3.8
# Saved to file : Amazon-Sr.DataScientist.json
# Cadre
# – New York, NY
# 4.7
# Saved to file : Cadre-SeniorDataScientist.json
# Aetna Inc.
# – New York, New York
# 3.4
# Saved to file : AetnaInc.-LeadDataScientist.json
# Amazon
# – Cambridge, MA
# 3.8
# Saved to file : Amazon-SeniorAppliedScientist.json
# Manulife
# – Boston, Massachusetts
# 3.6
# Saved to file : Manulife-SeniorDataScientist.json
# Workbridge Associates
# – Philadelphia, Pennsylvania
# 3.2
# Saved to file : WorkbridgeAssociates-PrincipalDataScientist.json
# Amazon
# – Seattle, WA
# 3.8
# Saved to file : Amazon-AppliedScientist-SelectionMonitoringTeam.json
# CyberCoders
# – San Francisco, CA
# 4.0
# Saved to file : CyberCoders-DataScientist-ComputerVision.json
# ZestFinance
# – Pittsburgh, PA, United States
# 3.8
# Saved to file : ZestFinance-DataScientist,MachineLearning.json
# Apex Life Sciences
# – Saint Charles, Missouri
# 2.6
# Saved to file : ApexLifeSciences-Scientist.json
# Ascent
# – Saint Paul, MN
# 3.0
# Saved to file : Ascent-Scientist.json
# Aptima
# – Arlington, VA
# 3.8
# Saved to file : Aptima-Scientist.json
# Navstar
# – McLean, VA
# 4.3
# Saved to file : Navstar-DataScientist(TS-SCIwithPolygraph).json
# The Salem Group
# – NAPERVILLE, IL
# 3.9
# Saved to file : TheSalemGroup-DataAnalyst.json
# Expedia
# – USA - Washington - Bellevue
# 3.8
# Saved to file : Expedia-DataScientistII-BusinessInsights.json
# Oracle
# – Reston, VA
# 3.4
# Saved to file : Oracle-DataScientist-GlobalITTeam.json
# Oracle
# – Charleston, SC
# 3.4
# Saved to file : Oracle-PrincipalDataScientist-MarketingCloud.json
# Conduent
# – Raleigh, North Carolina
# 2.5
# Saved to file : Conduent-DataScientist:DataAnalytics-MachineLearning.json
# Diverse Lynx
# – Bentonville, Arkansas
# 3.9
# Saved to file : DiverseLynx-DataScientist–OperationResearch.json
# KPMG International
# – Atlanta, Georgia
# 3.8
# Saved to file : KPMGInternational-Associate,DataScientist,Healthcare.json
# Berkadia
# – Ambler, PA, US
# 3.7
# Saved to file : Berkadia-DataAnalyst.json
# IQVIA
# – Plymouth Meeting, PA
# 3.4
# Saved to file : IQVIA-DataScientist-Programmer.json
# Nielsen
# – Columbia, MD
# 3.6
# Saved to file : Nielsen-Sr.DataScientist.json
# Siemens Healthineers
# – Hoffman Estates, Illinois
# 3.9
# Saved to file : SiemensHealthineers-Data-ImagingScientist.json
# Pfizer
# – CA - La Jolla
# 3.9
# Saved to file : Pfizer-PrincipalDataScientist,DrugSafety.json
# Merkle
# – Culver City, California
# 3.2
# Saved to file : Merkle-Analytics-Director-DataScientist.json
# Amazon
# – Westborough, MA
# 3.8
# Saved to file : Amazon-Sr.VisionResearchScientist.json
# OpenText
# – US, CA, San Mateo
# 2.9
# Saved to file : OpenText-DataScientist,AI.json
# Exact Sciences Corporation
# – Madison, WI
# 3.8
# Saved to file : ExactSciencesCorporation-ClinicalDevelopmentScientist.json
# Methodist Le Bonheur Healthcare
# – Memphis, TN
# 4.2
# Saved to file : MethodistLeBonheurHealthcare-IT-HealthcareInformationDataScientist.json
# CyberCoders
# – Newark, NJ
# 4.0
# Saved to file : CyberCoders-DataScientist-MachineLearningConsultant.json
# ASRC Federal Holding Company
# – Maryland, United States
# 3.5
# Saved to file : ASRCFederalHoldingCompany-DataAnalyst-Cashier.json
# Citi
# – Irving, Texas
# 3.5
# Saved to file : Citi-DataScientist-Sr.ProgrammerAnalyst.json
# Pfizer Canada Inc.
# – Groton, Connecticut
# 3.8
# Saved to file : PfizerCanadaInc.-PrincipalDataScientist,DrugSafety.json
# Amazon
# – Seattle, WA
# 3.8
# Saved to file : Amazon-SeniorDataEngineer.json
# ASRC Federal Holding Company
# – Maryland, United States
# 3.5
# Saved to file : ASRCFederalHoldingCompany-SrDataAnalyst.json
# ASRC Federal Holding Company
# – Maryland, United States
# 3.5
# Saved to file : ASRCFederalHoldingCompany-SrDataAnalyst-IETM.json
# Amazon
# – Seattle, WA
# 3.8
# Saved to file : Amazon-Sr.DataEngineer.json
# AIC
# – Durham, North Carolina
# 3.0
# Saved to file : AIC-DataScientist-BigDataW2Opportunity.json
# Lightspeed Systems
# – Austin, TX
# 4.2
# Saved to file : LightspeedSystems-DataAnalyticsDeveloper-DataScientist.json
# Blackberry
# – Irving, Texas
# 3.3
# Saved to file : Blackberry-DataScientistIntern-4MonthSpringTerm.json
# Ionis Pharmaceuticals
# – Carlsbad, CA
# 3.3
# Saved to file : IonisPharmaceuticals-Scientist.json
# Exponent
# – Bellevue, WA
# 3.2
# Saved to file : Exponent-Scientist.json
# United Services Automobile Association (USAA)
# – Phoenix, AZ
# NA
# Saved to file : UnitedServicesAutomobileAssociation(USAA)-DataScientistI-CollegeHire.json
# DuPont™ Danisco®
# – Wilmington, DE
# 2.8
# Saved to file : DuPont™Danisco®-DigitalAnalyst-DataScientists.json
# Berkadia
# – Ambler, PA, US
# 3.7
# Saved to file : Berkadia-DataAnalyst.json
# AiCure
# – Ny, NY
# 5.0
# Saved to file : AiCure-ResearchScientist.json
# Freddie Mac
# – Mclean, VA
# 3.8
# Saved to file : FreddieMac-DataScientist-QuantitativeAnalyticsProfessional.json
# Allstate
# – Charlotte, NC
# 3.5
# Saved to file : Allstate-D3-JuniorDataScientist1.json
# VF
# – Texas
# 3.5
# Saved to file : VF-Dickies-DataScientist(Ft.Worth).json
# Radian Group
# – Salt Lake City, UT
# 3.8
# Saved to file : RadianGroup-DataScientistinSaltLakeCity,UTatRadianGroupInc.json
# SRI International
# – Princeton, NJ
# 3.5
# Saved to file : SRIInternational-ComputerScientist(ComputerVision),VisionSystemsGroup.json
# Amazon
# – Sunnyvale, CA
# 3.8
# Saved to file : Amazon-ResearchScientist,AlexaAI-Speech-Audio.json
# Amazon
# – Seattle, WA
# 3.8
# Saved to file : Amazon-DataScientist,AdvertisingMeasurementandOptimization.json
# Fast Switch
# – Dearborn, MI
# 4.1
# Saved to file : FastSwitch-DataScientistModeling49981(SV1)(LJ4)(RS2).json
# Aristocrat Technologies
# – Tulsa
# 3.3
# Saved to file : AristocratTechnologies-Finance&amp;DataAnalyst,Senior.json
# National Aeronautics and Space Administration
# – Moffett Field, California
# 4.4
# Saved to file : NationalAeronauticsandSpaceAdministration-ComputerScientist,AST,DataAnalysis.json
# Goldman Sachs
# – US-NY-New York
# 3.9
# Saved to file : GoldmanSachs-GSAMTechnology-DataScienceandMachineLearningEngineer.json
# DataRobot
# – Washington, DC
# 4.3
# Saved to file : DataRobot-CustomerFacingDataScientist,AIServices.json
# Wittaff Inc.
# – Dallas, Texas
# NA
# Saved to file : WittaffInc.-FullStackDeveloper-DataScientist.json
# JPMorgan Chase
# – Columbus, OH
# 3.8
# Saved to file : JPMorganChase-VP,MarketingDataScientist(AnalyticsManager).json
# High Alpha
# – Indianapolis, IN
# NA
# Saved to file : HighAlpha-SeniorDataScientist.json
# ASRC Federal Holding Company
# – Maryland, United States
# 3.5
# Saved to file : ASRCFederalHoldingCompany-DataAnalyst-DriverMessenger.json
# Contingent Network Services
# – Reston, VA
# 3.5
# Saved to file : ContingentNetworkServices-PrincipalDataScientist,Cyber-Security.json
# Citadel Securities
# – Chicago, IL
# 4.9
# Saved to file : CitadelSecurities-QuantitativeResearcher–Intern(Asia).json
# Amazon
# – Seattle, WA
# 3.8
# Saved to file : Amazon-Sr.Manager,DataScience-SellingPartnerPaidServices.json
# First Soft Solutions
# – Mountain View, California
# 1.4
# Saved to file : FirstSoftSolutions-DatabaseEngineer-datascientist-.json
# Porch
# – Seattle
# 4.3
# Saved to file : Porch-SeniorManager,DataScience.json
# Amazon
# – Seattle, WA
# 3.8
# Saved to file : Amazon-SoftwareDevelopmentEngineer-Personalization,Recommendations,MachineLearning,DataScience.json
# GenapSys, Inc.
# – Redwood City, CA
# 3.5
# Saved to file : GenapSys,Inc.-SeniorMachineLearningScientist.json
# UnitedHealth Group
# – Minnetonka, MN
# 3.3
# Saved to file : UnitedHealthGroup-SeniorDataScientist-TwinCities,MNorTelecommute.json
# PayPal
# – San Jose
# 3.7
# Saved to file : PayPal-Head-DataScienceOperationalExcellence.json
# PepsiCo, Inc.
# – Plano, Texas
# 3.4
# Saved to file : PepsiCo,Inc.-DataScientist-SecurityNúmerodeEmpleo:159290BR-.json
# Chubb
# – Jersey City, NJ
# 3.3
# Saved to file : Chubb-ChubbAssociateProgram-Jr.DataScientist-DataEngineer.json
# Getty Images
# – New York, NY
# 3.6
# Saved to file : GettyImages-DataAnalyst.json
# Acara Solutions
# – Walpole, MA, United States
# 3.1
# Saved to file : AcaraSolutions-Scientist.json
# Uchicago Argonne
# – Lemont, IL
# 4.0
# Saved to file : UchicagoArgonne-ComputerScientist.json
# Talium Advisors
# – Pearl River, NY
# NA
# Saved to file : TaliumAdvisors-Scientist.json
# Madico, Inc.
# – Woburn, MA
# 3.9
# Saved to file : Madico,Inc.-Sr.Scientist.json
# newcareers
# – Indianapolis, IN
# 5.0
# Saved to file : newcareers-PredictiveAnalyticsScientist.json
# Keurig Dr Pepper
# – USA-Massachusetts-MA - Burlington
# 3.7
# Saved to file : KeurigDrPepper-ProductDevelopmentScientistI.json
# Fast Switch
# – Dearborn, MI
# 4.1
# Saved to file : FastSwitch-DataScientistModeling49981(SV1)(LJ4)(RS2)-BHJOB13738_49981GD.json
# Radiance Technologies
# – Dayton, Ohio, United States
# 3.7
# Saved to file : RadianceTechnologies-PersistentInfrared(PIR)Scientist-Developer.json
# Lubrizol
# – Hazelwood
# 3.7
# Saved to file : Lubrizol-DataScientistIntern-PhDStudent.json
# American Civil Liberties Union
# – New York
# 3.0
# Saved to file : AmericanCivilLibertiesUnion-QuantitativeSocialScientist[DATA-17],Data&amp;Analytics,NY.json
# Bristol Myers Squibb
# – Princeton, NJ
# 3.6
# Saved to file : BristolMyersSquibb-CenterforObservationalResearchandDataScience-SeniorDataScientist.json
# Aon
# – US-MA-Boston
# 3.4
# Saved to file : Aon-ComputerScientistConsultant.json
# Ancestry
# – San Francisco
# 3.0
# Saved to file : Ancestry-BioinformaticsDataScientistManager.json
# Allstate
# – Chicago, IL
# 3.5
# Saved to file : Allstate-Sr.DataScientist:ComputerVision&amp;DeepLearning.json
# BAE Systems
# – Arlington, Virginia
# 3.5
# Saved to file : BAESystems-SeniorPrincipalScientist,DataScience.json
# The Aerospace Corporation
# – El Segundo, CA
# 3.7
# Saved to file : TheAerospaceCorporation-Sr.DataScientist(Cross-DomainAnalysis)(L2-L3).json
# L.A. Care Health Plan
# – Los Angeles, California, US
# 3.0
# Saved to file : L.A.CareHealthPlan-DataAnalystIII,BusinessInsights.json
# Ciklum
# – Kyiv
# 3.7
# Saved to file : Ciklum-SeniorDataScientistforTubularLabs.json
# Allstate Insurance Company
# – Washington, Washington
# 3.5
# Saved to file : AllstateInsuranceCompany-Sr.DataScientist-NLPDeepLearning.json
# Teachers Pay Teachers
# – New York, NY
# 4.9
# Saved to file : TeachersPayTeachers-AnalyticsManager.json
# CitiGroup
# – NAM-USA-DE-Wilmington
# 3.5
# Saved to file : CitiGroup-SVP,DigitalBusinessAnalyticsDataScientist.json
# Keurig Dr Pepper
# – USA-Massachusetts-MA - Burlington
# 3.7
# Saved to file : KeurigDrPepper-ProductDevelopmentScientistII.json
# Comlinkdata
# – Boston, MA
# 4.5
# Saved to file : Comlinkdata-Mid-LeveltoSeniorDataEngineer.json
# Exact Sciences Corporation
# – Madison, WI
# 3.8
# Saved to file : ExactSciencesCorporation-LeadCertifiedClinicalLaboratoryScientist-Tuesday-Friday,2:30PM-1:00AM-$1000signonbonus!.json
# Cameron Craig Group
# – Paramus, NJ
# 5.0
# Saved to file : CameronCraigGroup-CNSScientist.json
# Celgene
# – San Diego, CA US
# 3.8
# Saved to file : Celgene-ScientistI.json
# The College Board
# – San Juan, PR
# 3.7
# Saved to file : TheCollegeBoard-ResearchScientist.json
# ARCADIS US
# – SC, Greenville
# 3.7
# Saved to file : ARCADISUS-Scientist1.json
# Koch Industries
# – ORANGE, Texas
# 4.1
# Saved to file : KochIndustries-AnalyticalScientist.json
# Kla-tencor
# – Milpitas, CA
# 3.7
# Saved to file : Kla-tencor-ResearchScientist.json
# Indeed
# – Austin, TX
# 3.5
# Saved to file : Indeed-DataEngineer.json
# NFP
# – Warrington,PA
# 3.7
# Saved to file : NFP-DataAnalyst.json
# Temple University
# – Philadelphia, PA
# 4.0
# Saved to file : TempleUniversity-AssociateScientist.json
# Genentech
# – South San Francisco, California
# 4.0
# Saved to file : Genentech-Scientist,Biochemical&amp;CellularPharmacology,GenentechResearch.json
# University of Chicago
# – Chicago, Illinois
# 4.0
# Saved to file : UniversityofChicago-ComputationalScientist.json
# UNC-Chapel Hill
# – Chapel Hill, NC
# 4.0
# Saved to file : UNC-ChapelHill-BioinformaticsScientist.json
# Atreca
# – Redwood City, CA
# 4.7
# Saved to file : Atreca-ScientistI-II,TranslationalBiology.json
# Cameron Craig Group
# – Indianapolis, IN
# 5.0
# Saved to file : CameronCraigGroup-PredictiveAnalyticsScientist.json
# HOVER
# – San Francisco, CA
# 4.8
# Saved to file : HOVER-DataEngineer.json
# Microsoft Corporation
# – Bellevue, WA
# 4.1
# Saved to file : MicrosoftCorporation-AppliedScientist2.json
# Select Source International
# – Andover, MA
# 4.4
# Saved to file : SelectSourceInternational-QualityControlScientist.json
# Department of the Air Force
# – Baltimore, MD
# 4.2
# Saved to file : DepartmentoftheAirForce-ComputerScientist.json
# SPINS, LLC
# – Chicago, IL
# 3.8
# Saved to file : SPINS,LLC-DataEngineer.json
# Exact Sciences Corporation
# – Madison, WI
# 3.8
# Saved to file : ExactSciencesCorporation-CertifiedClinicalLaboratoryScientistI-Tuesday-Friday,7:30pm-6:00amshift-$1,000signonbonus!.json
# Citibank
# – Wilmington, DE (US)
# 3.4
# Saved to file : Citibank-SVP,DigitalBusinessAnalyticsDataScientist.json
# BOLD
# – San Francisco, CA
# 3.5
# Saved to file : BOLD-SeniorProductDataAnalyst.json
# PwC
# – New York, NY
# 3.7
# Saved to file : PwC-AdvancedRiskComplianceAnalyticsManager.json
# Department of the Navy
# – Washington, DC (US)
# 4.0
# Saved to file : DepartmentoftheNavy-COMPUTERSCIENTIST.json
# Exact Sciences Corporation
# – Madison, WI
# 3.8
# Saved to file : ExactSciencesCorporation-LeadCertifiedClinicalLaboratoryScientist-Tuesday-Friday,2:30PM-1:00AM-$1,000signonbonus!.json
# Exact Sciences Corporation
# – Madison, WI
# 3.8
# Saved to file : ExactSciencesCorporation-Lead,CertifiedClinicalLaboratoryScientist-Saturday-Tuesday,2:30pm-1:00amshift-$1,000signonbonus!.json
# Exact Sciences Corporation
# – Madison, WI
# 3.8
# Saved to file : ExactSciencesCorporation-LeadCertifiedClinicalLaboratoryScientist-Tuesday-Friday,7:30pm-6:00am-$1,000signonbonus!.json
# Glu Mobile
# – San Francisco, CA, United States
# 3.6
# Saved to file : GluMobile-SeniorDataEngineer.json
# Workday
# – USA, CA, Pleasanton
# 3.8
# Saved to file : Workday-PerformanceScientist.json
# New York Life
# – New York, NY
# 3.5
# Saved to file : NewYorkLife-CVP-DataScientist&amp;InsightsLeader-InternalAuditAnalytics.json
# Georgia-Pacific
# – ORANGE, Texas
# 3.4
# Saved to file : Georgia-Pacific-AnalyticalScientist.json
# Antuit, Inc.
# – Frisco, Texas
# 3.5
# Saved to file : Antuit,Inc.-ArtificialIntelligenceScientist.json
# Ascent
# – San Diego, CA
# 3.0
# Saved to file : Ascent-AssociateScientist.json
# Navarro Inc.
# – Grand Junction, CO
# 3.3
# Saved to file : NavarroInc.-EnvironmentalScientist-TechnicalReportWriter.json
# Cogent Professionals
# – Indianapolis, IN
# 3.7
# Saved to file : CogentProfessionals-ApplicationsScientist.json
# Dawar Consulting, Inc.
# – Santa Clara, California
# NA
# Saved to file : DawarConsulting,Inc.-ScientistI.json
# NYU Langone Medical Center
# – New York, NY
# 3.8
# Saved to file : NYULangoneMedicalCenter-ResearchScientist.json
# Roche
# – United States, California, Pleasanton
# 3.8
# Saved to file : Roche-SeniorScientist.json
# Temple University
# – Philadelphia, PA
# 4.0
# Saved to file : TempleUniversity-AssociateScientist.json
# Brown-Forman
# – Louisville, KY
# 4.5
# Saved to file : Brown-Forman-AssociateScientist-ProductInsights.json
# Invitae
# – San Francisco, CA
# 4.2
# Saved to file : Invitae-DataEngineer.json
# Zolon Tech
# – Morrisville, NC
# 3.7
# Saved to file : ZolonTech-SeniorAssociateScientist.json
# Amazon
# – Seattle, WA
# 3.8
# Saved to file : Amazon-DataAnalyst-Alexa-French.json
# Niantic
# – Sunnyvale, CA
# 4.7
# Saved to file : Niantic-DataScienceLead.json
# Amazon
# – Seattle, WA
# 3.8
# Saved to file : Amazon-ResearchScientist-PrimeAir.json
# Compunnel Software Group Inc.
# – South San Francisco, CA
# 3.6
# Saved to file : CompunnelSoftwareGroupInc.-AssociateScientistII.json
# Delta Search Labs
# – Cambridge, Massachusetts
# 1.0
# Saved to file : DeltaSearchLabs-ComputationalBiomedicalResearchScientist.json
# Centers for Disease Control and Prevention
# – New York, New York
# 3.9
# Saved to file : CentersforDiseaseControlandPrevention-HealthScientist.json
# Mahisoft
# – , US
# 4.8
# Saved to file : Mahisoft-DataEngineer.json
# LabCorp
# – San Diego, CA
# 2.9
# Saved to file : LabCorp-ComputationalBiologist-BioinformaticsDataScientist-Sequenom(Remote-locationisflexible).json
# Department of the Air Force
# – Patrick AFB, Florida
# 4.2
# Saved to file : DepartmentoftheAirForce-COMPUTERSCIENTIST.json
# Integrity Applications
# – Kihei, Hawaii
# 4.4
# Saved to file : IntegrityApplications-MachineLearningEngineer.json
# Amazon
# – Seattle, WA
# 3.8
# Saved to file : Amazon-DataEngineer,AdvertisingMeasurement.json
# Zea Biosciences Corp
# – Walpole, MA
# NA
# Saved to file : ZeaBiosciencesCorp-PlantScientist.json
# WeWork
# – New York, New York, United States
# 3.3
# Saved to file : WeWork-SeniorDataEngineer.json
# Pfizer
# – United States - North Carolina - Sanford
# 3.9
# Saved to file : Pfizer-TechnicalScientist.json
# Department of the Navy
# – Washington, DC (US)
# 4.0
# Saved to file : DepartmentoftheNavy-COMPUTERSCIENTIST.json
# Analog Devices
# – Boston, Massachusetts
# 3.8
# Saved to file : AnalogDevices-SeniorResearchScientistorResearchScientist.json
# Amazon
# – Seattle, WA
# 3.8
# Saved to file : Amazon-Sr.DataEngineer-SalesOps.json
# City of New York
# – New York, NY (US)
# 3.5
# Saved to file : CityofNewYork-DataAnalyst.json
# NORC at the University of Chicago
# – Bethesda, MD
# 2.9
# Saved to file : NORCattheUniversityofChicago-ResearchScientist.json
# Microsoft Corporation
# – Redmond, WA
# 4.1
# Saved to file : MicrosoftCorporation-DataEngineer.json
# University of Florida
# – Gainesville, FL
# 4.2
# Saved to file : UniversityofFlorida-BiologicalScientistII.json
# WeWork
# – Boston, MA
# 3.3
# Saved to file : WeWork-DataEngineer.json
# Kforce
# – Louisville, KY
# 3.9
# Saved to file : Kforce-DataAnalyst.json
# NeuroLeadership Institute
# – Los Angeles, CA
# 3.8
# Saved to file : NeuroLeadershipInstitute-DataAnalyst.json
# Mteq
# – Lorton, VA
# 3.1
# Saved to file : Mteq-JuniorScientist.json
# Swift Biosciences
# – Ann Arbor, MI
# 4.0
# Saved to file : SwiftBiosciences-BioinformaticsScientistII.json
# SAIC
# – Chantilly, VA
# 3.5
# Saved to file : SAIC-MarineScientist.json
# Mteq
# – Springfield, VA, VA
# 3.1
# Saved to file : Mteq-SpectralScientist.json
# Alpha Consulting Corp.
# – Devens, Massachusetts
# 4.0
# Saved to file : AlphaConsultingCorp.-AssociateScientist-ProcessDevelopmentAnalytics.json
# Ascension
# – Pensacola, FL
# 3.1
# Saved to file : Ascension-MedicalLabScientist(MLS).json
# Genentech
# – South San Francisco, California
# 4.0
# Saved to file : Genentech-PHCSeniorScientist,Omics.json
# PPD
# – Boston, MA
# 3.4
# Saved to file : PPD-ResearchScientist-SmallMolecule-HPLC-TOC-DataReview-Stability-GMP.json
# CapTech
# – Richmond, VA
# 4.0
# Saved to file : CapTech-BigDataEngineer.json
# PPD
# – Boston, MA, United States
# 3.4
# Saved to file : PPD-ResearchScientist-SmallMolecule-HPLC-TOC-DataRevi.json
# System One
# – Kenilworth, NJ
# 3.3
# Saved to file : SystemOne-Scientist-III.json
# Fast Switch
# – Dearborn, MI
# 4.1
# Saved to file : FastSwitch-AnalyticsScientist48664(SV1).json
# Fitbit
# – Boston, MA
# 3.1
# Saved to file : Fitbit-LeadDataEngineer,DataWarehouse.json
# Fast Switch
# – Cambridge, MA, United States
# 4.1
# Saved to file : FastSwitch-Sr.Pharmacovigilance(PV)Scientist.json
# TechData Service Company LLC
# – Summit, NJ
# 3.7
# Saved to file : TechDataServiceCompanyLLC-AssociateScientist(AnalyticalDevelopment.json
# Commonwealth Care Alliance
# – Boston, MA
# 3.5
# Saved to file : CommonwealthCareAlliance-ClaimsPolicyDataAnalyst.json
# Vitaver &amp; Associates, Inc.
# – Lake County, IL
# 4.1
# Saved to file : Vitaver&amp;Associates,Inc.-EDODataEngineerIII.json
# CyberCoders
# – San Diego, CA
# 4.0
# Saved to file : CyberCoders-SeniorScientist,Bioinformatics.json
# Uber
# – San Francisco, California, United States
# 4.2
# Saved to file : Uber-DataAnalystManager,SafetyandInsurance.json
# PPD
# – Boston, MA, United States
# 3.4
# Saved to file : PPD-SeniorScientist-SmallMolecule-HPLC-DataReview-Sta.json
# PPD
# – Boston, MA
# 3.4
# Saved to file : PPD-SeniorScientist-SmallMolecule-HPLC-DataReview-Stability-GMP.json
# EY
# – Mc Lean, VA
# 3.7
# Saved to file : EY-Government&amp;PublicSector-Senior-TechnologyConsulting-DataScientist-Tysons,VA-SECRETC.json
# Charles River Laboratories, Inc.
# – Shrewsbury, MA
# 3.1
# Saved to file : CharlesRiverLaboratories,Inc.-ScientistII.json
# People Solutions
# – Redwood City, CA
# NA
# Saved to file : PeopleSolutions-ScientistI.json
# University of Iowa
# – Iowa City, IA
# 4.2
# Saved to file : UniversityofIowa-AsstResearchScientist-Engin.json
# ICF
# – Atlanta, GA
# 3.6
# Saved to file : ICF-DataAnalyst.json
# PRA Health Sciences
# – United States-Pennsylvania-Blue Bell
# 3.4
# Saved to file : PRAHealthSciences-AnalyticsConsultant.json
# Horizontal Integration
# – Centennial, CO
# 4.0
# Saved to file : HorizontalIntegration-DataScience-MachineLearning.json
# Northside Hospital
# – Atlanta, GA
# 4.5
# Saved to file : NorthsideHospital-ClinicalLabScientist(MolecularLab).json
# Recruitomics Consulting
# – Cambridge, MA
# 5.0
# Saved to file : RecruitomicsConsulting-Senior-Scientist,Oncology.json
# Bristol-Myers Squibb
# –
# 3.6
# Saved to file : Bristol-MyersSquibb-AnalyticalScientist.json
# Button Inc
# – New York, NY
# 5.0
# Saved to file : ButtonInc-DataAnalyst,Revenue.json
# Enjoy
# – Menlo Park, CA
# 3.3
# Saved to file : Enjoy-DataAnalyst.json
# Tech Firefly
# – Belmont, CA
# 5.0
# Saved to file : TechFirefly-DataAnalyst.json
# Indeed
# – Austin, TX
# 3.5
# Saved to file : Indeed-DataScienceLeader.json
# Womply
# – San Francisco, California
# 3.6
# Saved to file : Womply-DataEngineer.json
# University of Washington
# – Seattle, WA
# 4.1
# Saved to file : UniversityofWashington-RESEARCHSCIENTIST4.json
# AmerisourceBergen
# – Chesterbrook, PA
# 3.0
# Saved to file : AmerisourceBergen-DataEngineer,MDM.json
# Zepto Life Technology
# – Saint Paul, MN
# 5.0
# Saved to file : ZeptoLifeTechnology-AssayDevelopmentScientist.json
# Ipsy
# – San Mateo, CA, United States
# 3.2
# Saved to file : Ipsy-MachineLearningEngineer.json
# CorTech, LLC
# – Carlsbad, CA
# 2.9
# Saved to file : CorTech,LLC-ScientistII,ProteinPurification.json
# Perspecta
# – Springfield, VA
# 2.8
# Saved to file : Perspecta-NSGStandardsDataModeler.json
# Flagship Pioneering
# – Cambridge, MA
# 4.0
# Saved to file : FlagshipPioneering-SeniorScientist,CellBiology.json
# University Corporation for Atmospheric Research
# – Boulder, Colorado
# 3.8
# Saved to file : UniversityCorporationforAtmosphericResearch-ProjectScientistIII-IV.json
# Headway Workforce Solutions
# – Atlanta, GA
# 3.1
# Saved to file : HeadwayWorkforceSolutions-PrincipalResearchScientist.json
# Planet Pharma
# – Thousand Oaks, CA
# 4.1
# Saved to file : PlanetPharma-AssociateScientistAFP.json
# Avista Pharma
# – Durham, North Carolina, United States
# 3.1
# Saved to file : AvistaPharma-CrystallizationScientist.json
# Illumina
# – San Diego, California
# 4.2
# Saved to file : Illumina-AssociateIntegrationScientist2.json
# System One
# – Boston, MA
# 3.3
# Saved to file : SystemOne-Scientist-II.json
# Komodo Health
# – San Francisco, CA
# 4.1
# Saved to file : KomodoHealth-SeniorDataEngineer.json
# Department of Agriculture
# – Lubbock, Texas
# 4.1
# Saved to file : DepartmentofAgriculture-SupervisoryAgriculturalScientist.json
# Perkinelmer
# – Waltham
# 3.1
# Saved to file : Perkinelmer-SeniorScientist.json
# BARK
# – New York, NY
# 3.5
# Saved to file : BARK-DataAnalyst-BusinessIntelligenceAnalyst.json
# Balyasny Asset Management
# – Chicago
# 3.9
# Saved to file : BalyasnyAssetManagement-InvestmentDataAnalyst.json
# Poly-Med, Inc.
# – Anderson, South Carolina
# 4.7
# Saved to file : Poly-Med,Inc.-QualityControlScientist.json
# US Department of Defense
# – Mobile, AL
# 4.0
# Saved to file : USDepartmentofDefense-Interdisciplinary(PhysicialScientist-Biologist).json
# Columbia University
# – New York City, New York
# 4.0
# Saved to file : ColumbiaUniversity-AssociateResearchScientist.json
# Tradesy
# – Santa Monica, CA
# 3.2
# Saved to file : Tradesy-DataEngineer.json
# W.L. Gore
# – United States-Maryland-Elkton
# 3.3
# Saved to file : W.L.Gore-PolymerScientist.json
# ...
# Arcus Biosciences, Inc.
# – Hayward, CA
# NA
# Saved to file : ArcusBiosciences,Inc.-ClinicalScientist.json
# Forbes Media
# – Jersey City, NJ
# 3.0
# Saved to file : ForbesMedia-SeniorDataScienceEngineer.json
# Cedars-Sinai
# – Los Angeles, California
# 3.8
# Saved to file : Cedars-Sinai-PostdoctoralScientist(TelomeraseBiology).json
# Cedars-Sinai
# – Los Angeles, California
# 3.8
# Saved to file : Cedars-Sinai-PostdoctoralScientist,GianiLab.json
# VNSNY
# – New York, NY
# 3.6
# Saved to file : VNSNY-SeniorResearchScientist.json
# Enanta Pharmaceuticals
# – Watertown, MA
# 4.5
# Saved to file : EnantaPharmaceuticals-AssociateScientist,DrugMetabolismandPharmacokinetics(DMPK)Studies.json
# AI Therapeutics
# – Guilford, Connecticut
# NA
# Saved to file : AITherapeutics-Sr.DeepLearningScientist.json
# Vertex Pharmaceuticals
# – San Diego, CA
# 3.7
# Saved to file : VertexPharmaceuticals-TemporaryResearchScientist,MedicinalChemistry.json
# CyberCoders
# – Sausalito, CA
# 4.0
# Saved to file : CyberCoders-SeniorLeadDataAnalyst.json
# CorTech, LLC
# – North Chicago, IL
# 2.9
# Saved to file : CorTech,LLC-AssociateScientistI.json
# Ferguson Enterprises
# – Newport News, VA
# 3.4
# Saved to file : FergusonEnterprises-SustainabilityDataAnalyst.json
# CTG
# – Carlsbad, CA
# 3.1
# Saved to file : CTG-ProteinPurificationScientist.json
# UW Medicine
# – Seattle, WA
# 3.3
# Saved to file : UWMedicine-X-RAYCRYSTALLOGRAPHERSTAFFSCIENTIST.json
# AbbVie
# – North Chicago, USA
# 3.7
# Saved to file : AbbVie-AssociateScientistI-II,AnalyticalChemistry.json
# Boeing
# – St. Louis, Missouri
# 3.5
# Saved to file : Boeing-SystemsandDataAnalyst.json
# ICF
# – Austin, TX
# 3.6
# Saved to file : ICF-ResearchScientistII.json
# Asuragen
# – Austin, TX
# 3.2
# Saved to file : Asuragen-FieldApplicationScientist.json
# Amazon
# – Seattle, WA
# 3.8
# Saved to file : Amazon-DataEngineer,Alexa.json
# Apple
# – Santa Clara, California
# 4.0
# Saved to file : Apple-Siri-SeniorDataPrivacyEngineer.json
# Cognitive Scale
# – Austin, TX
# NA
# Saved to file : CognitiveScale-MachineLearningResearchScientist.json
# Vaco - Houston
# – Houston, Texas
# 5.0
# Saved to file : Vaco-Houston-AzureETLDataEngineer-Fulltime.json
# AbbVie
# – North Chicago, USA
# 3.7
# Saved to file : AbbVie-SeniorScientistII-II,Pathology,TranslationalOncology.json
# PCI Synthesis
# – Newburyport
# 2.9
# Saved to file : PCISynthesis-Ph.D.MethodDevelopmentScientist.json
# Beckman Coulter
# – United States-FL-Miami
# 3.1
# Saved to file : BeckmanCoulter-QualityAssuranceScientistII.json
# LabCorp
# – Saint Paul, MN
# 2.9
# Saved to file : LabCorp-CertifyingScientistTrainer.json
# Terracon
# – Ft. Lauderdale, FL
# 3.5
# Saved to file : Terracon-ProjectScientist.json
# Pfizer
# – Saint Louis, MO
# 3.9
# Saved to file : Pfizer-SeniorScientist(PhD),BioassayandImpurityTesting.json
# Keysight Technologies
# – Santa Clara, CA
# 3.9
# Saved to file : KeysightTechnologies-BusinessProcessRepresentative-DataManager.json
# CoreLogic
# – Oakland, California
# 2.8
# Saved to file : CoreLogic-Principal,Scientist.json
# Poseida Therapeutics
# – San Diego
# 4.5
# Saved to file : PoseidaTherapeutics-ResearchScientistCARTcells.json
# Palo Alto Networks
# – Santa Clara, CA, United States
# 3.7
# Saved to file : PaloAltoNetworks-Intern-DataScience.json
# Uplift
# – Menlo Park / San Francisco
# 4.4
# Saved to file : Uplift-SeniorDataEngineer.json
# Vertex Pharmaceuticals
# – San Diego, CA
# 3.7
# Saved to file : VertexPharmaceuticals-ResearchScientistII-SeniorResearchScientist,ComputationalGenomics.json
# Roche
# – United States, California, South San Francisco
# 3.8
# Saved to file : Roche-PHC,DataScience,Imaging.json
# AHMC Anaheim Regional Medical Center LP
# – Anaheim, CA
# 2.9
# Saved to file : AHMCAnaheimRegionalMedicalCenterLP-ClinicalLabScientist(Microbiology).json
# Enanta Pharmaceuticals
# – Watertown, MA
# 4.5
# Saved to file : EnantaPharmaceuticals-AssociateScientist,DrugMetabolismandPharmacokinetics(DMPK)Studies.json
# Allied Minds
# – Fremont, CA
# 4.0
# Saved to file : AlliedMinds-SpinMemory-MRAMDeviceCharacterizationScientist-Engineer.json
# Cedars-Sinai
# – Los Angeles, California
# 3.8
# Saved to file : Cedars-Sinai-PostdoctoralScientist(CancerInstitute).json
# Department of Defense
# – Fort Meade, Maryland
# 3.2
# Saved to file : DepartmentofDefense-ComputerScientist-ElectronicsEngineer-ComputerEngineer.json
# AbbVie
# – North Chicago, USA
# 3.7
# Saved to file : AbbVie-Scientist,Cellular-MolecularBiology–TranslationalOncology.json
# AbbVie
# – North Chicago, USA
# 3.7
# Saved to file : AbbVie-AssociateScientistI-II,AnalyticalChemistry.json
# Detroit Trading Company
# – Birmingham, MI
# 4.7
# Saved to file : DetroitTradingCompany-DataAnalyst.json
# STRIVR
# – Los Angeles, CA
# 5.0
# Saved to file : STRIVR-BusinessIntelligenceAnalyst.json
# Apple
# – Santa Clara, California
# 4.0
# Saved to file : Apple-Siri-SeniorDataPrivacyEngineer.json
# Cargill
# – Plymouth
# 3.5
# Saved to file : Cargill-SweetnessProductDevelopmentScientist.json
# Pfizer Inc.
# – Groton, Connecticut
# 3.9
# Saved to file : PfizerInc.-BioanalyticalAssociateScientist,Non-Regulated(non-PhD).json
# Bristol Myers Squibb
# – Princeton, NJ
# 3.6
# Saved to file : BristolMyersSquibb-AssociateResearchScientist,ProteinCrystallization.json
# Intertek
# – Whitehouse, NJ
# 2.7
# Saved to file : Intertek-ResearchScientist-TraceOrganics.json
# Corning
# – Painted Post, NY
# 3.7
# Saved to file : Corning-SrResearchScientist-MechanicsandReliabilitySciences.json
# Sky RPO
# – Dallas, Texas
# NA
# Saved to file : SkyRPO-Sr.OperationsResearchScientist.json
# Postmates Inc.
# – San Francisco, CA
# 3.3
# Saved to file : PostmatesInc.-SoftwareDataEngineer.json
# shopkick
# – Redwood City, CA
# 3.5
# Saved to file : shopkick-DirectorofAnalytics&amp;DataScience.json
# Amgen
# – Thousand Oaks, California
# 3.7
# Saved to file : Amgen-AssociateScientist-NextGenSequencing.json
# AbbVie
# – South San Francisco, USA
# 3.7
# Saved to file : AbbVie-SeniorScientistI,AssayDevelopment(ADCDiscovery).json
# Nevada National Security Site
# – Mercury, NV
# 3.0
# Saved to file : NevadaNationalSecuritySite-Senior-PrincipalScientist.json
# ICF
# – Washington, DC
# 3.6
# Saved to file : ICF-DataVisualizationSpecialist.json
# Vivid Seats
# – Chicago, IL, United States
# 3.5
# Saved to file : VividSeats-DataEngineerII-Platform.json
# Sorrento Therapeutics
# – San Diego, CA
# 2.6
# Saved to file : SorrentoTherapeutics-Scientist-Sr.Scientist,ExperimentalImmuno-Oncology.json
# Shell
# –
# 3.8
# Saved to file : Shell-DirectorofDataScience,EnergyPlatform.json
# Princeton Information Ltd
# – Tampa, FL
# 3.7
# Saved to file : PrincetonInformationLtd-SeniorAnalyst,DataScience.json
# Pfizer
# – United States - New York - Pearl River
# 3.9
# Saved to file : Pfizer-SeniorAssociateScientist–TargetedImmunotherapy.json
# TechUSA
# – Gaithersburg, MD
# 2.8
# Saved to file : TechUSA-HPLCAssociateScientist.json
# Cruise Automation
# – San Francisco, CA
# 3.9
# Saved to file : CruiseAutomation-SeniorSoftwareEngineer-DataScience.json
# State of Washington
# – Olympia, WA
# 3.7
# Saved to file : StateofWashington-GeologyDataSteward.json
# Chase
# – New York
# 3.6
# Saved to file : Chase-DataAnalyticsInfrastructureManager.json
# Department of the Army
# – Fort Gillem, Georgia
# 4.0
# Saved to file : DepartmentoftheArmy-PHYSICALSCIENTIST(FORENSICLATENTPRINTEXAMINER).json
# Weill Cornell Medical College
# – New York, NY
# 3.7
# Saved to file : WeillCornellMedicalCollege-DataControlCoordinator.json
# Lonza
# – US - Bend
# 2.8
# Saved to file : Lonza-Scientist,ProductDevelopment.json
# Rich Products
# – Buffalo, NY, US, 14213-1701
# 3.0
# Saved to file : RichProducts-R&amp;DFoodScientist.json
# ICF
# – Trenton, NJ
# 3.6
# Saved to file : ICF-ReportingDataAnalyst.json
# Pfizer
# – United States - Connecticut - Groton
# 3.9
# Saved to file : Pfizer-AssociateScientist,AnalyticalChemistry,Pharmaceuticals.json
# Terracon
# – Baton Rouge, LA
# 3.5
# Saved to file : Terracon-SeniorStaffScientist.json
# 5D Technology Solutions, Inc
# – Frederick, MD
# NA
# Saved to file : 5DTechnologySolutions,Inc-ComputerScientistLvl2.json
# Cargill
# – Plymouth
# 3.5
# Saved to file : Cargill-SweetnessProductDevelopmentScientist.json
# Eurofins Scientific
# – PA, Malvern
# 2.7
# Saved to file : EurofinsScientific-ProteinCharacterizationScientist.json
# Fisker Inc
# – Torrance, CA
# NA
# Saved to file : FiskerInc-BatteryTechnologyCellDevelopment,SeniorScientist.json
# ICF
# – Austin, TX
# 3.6
# Saved to file : ICF-ResearchScientistIII.json
# ICF
# – Annapolis, MD
# 3.6
# Saved to file : ICF-EnvironmentalDataValidationChemist.json
# Macropace Technologies
# – Seattle, WA
# 4.8
# Saved to file : MacropaceTechnologies-DataAnalyst.json
# Syngenta Global
# – Clinton, MI
# NA
# Saved to file : SyngentaGlobal-AgronomicResearchScientist-Clinton,Illinois.json
# Moderna Theraputics
# – Cambridge, MA
# NA
# Saved to file : ModernaTheraputics-Scientist,AnalyticalDevelopment.json
# Eurofins Scientific, Inc.
# – Malvern, PA, Pennsylvania
# 2.7
# Saved to file : EurofinsScientific,Inc.-ProcessAnalyticalScientist.json
# Digital Reasoning
# – Franklin, TN
# 3.1
# Saved to file : DigitalReasoning-SeniorMachineLearningEngineer.json
# Elsevier
# – New York, New York, United States
# 3.4
# Saved to file : Elsevier-ProductManager-Data&amp;Analytics.json
# UCLA Library
# – Los Angeles, CA
# 4.3
# Saved to file : UCLALibrary-SciencesDataLibrarian.json
# Eurofins Scientific
# – PA, Malvern
# 2.7
# Saved to file : EurofinsScientific-CellCultureScientist.json
# Amazon
# – Seattle, WA
# 3.8
# Saved to file : Amazon-AppliedScientist,NaturalLanguageProcessing-AmazonAI.json
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-df2050e77877> in <module>()
#      25     for element in elements:
#      26         try:
# ---> 27             x_button = browser.find_by_css('div.xBtn')
#      28             if x_button:
#      29                 x_button.click()
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/splinter/driver/webdriver/__init__.py in find_by_css(self, css_selector)
#     386         return self.find_by(
#     387             self.driver.find_elements_by_css_selector, css_selector, original_find='css',
# --> 388             original_query=css_selector)
#     389
#     390     def find_by_xpath(self, xpath, original_find=None, original_query=None):
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/splinter/driver/webdriver/__init__.py in find_by(self, finder, selector, original_find, original_query)
#     371         while time.time() < end_time:
#     372             try:
# --> 373                 elements = finder(selector)
#     374                 if not isinstance(elements, list):
#     375                     elements = [elements]
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in find_elements_by_css_selector(self, css_selector)
#     611             elements = driver.find_elements_by_css_selector('.foo')
#     612         """
# --> 613         return self.find_elements(by=By.CSS_SELECTOR, value=css_selector)
#     614
#     615     def execute_script(self, script, *args):
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in find_elements(self, by, value)
#     993         return self.execute(Command.FIND_ELEMENTS, {
#     994             'using': by,
# --> 995             'value': value})['value'] or []
#     996
#     997     @property
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     316
#     317         params = self._wrap_value(params)
# --> 318         response = self.command_executor.execute(driver_command, params)
#     319         if response:
#     320             self.error_handler.check_response(response)
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     373         data = utils.dump_json(params)
#     374         url = '%s%s' % (self._url, path)
# --> 375         return self._request(command_info[0], url, body=data)
#     376
#     377     def _request(self, method, url, body=None):
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     395             if body and method != 'POST' and method != 'PUT':
#     396                 body = None
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      68             return self.request_encode_body(method, url, fields=fields,
#      69                                             headers=headers,
# ---> 70                                             **urlopen_kw)
#      71
#      72     def request_encode_url(self, method, url, fields=None, headers=None,
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     146         extra_kw.update(urlopen_kw)
#     147
# --> 148         return self.urlopen(method, url, **extra_kw)
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     319             response = conn.urlopen(method, url, **kw)
#     320         else:
# --> 321             response = conn.urlopen(method, u.request_uri, **kw)
#     322
#     323         redirect_location = redirect and response.get_redirect_location()
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# /anaconda3/envs/PythonData/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# /anaconda3/envs/PythonData/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /anaconda3/envs/PythonData/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /anaconda3/envs/PythonData/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:
